# %% [markdown]
# * How to sort columns like, artist_y, artist_x, ..., using select

# %% [markdown]
# ## Read in data

# %%
import pandas as pd

import pickle

lib1 = pickle.load(open('../data/2016-07-15/itl.p', 'rb'))
lib2 = pickle.load(open('../data/2019-07-31/itl.p', 'rb'))

# %load_ext blackcellmagic

# %%
raw_data1 = [s[1].ToDict() for s in lib1.songs.items()]
raw_data2 = [s[1].ToDict() for s in lib2.songs.items()]

# %%
from siuba import *
from datetime import datetime
from time import mktime

convert_date = (_
    .dropna()
    .apply(lambda x: datetime.fromtimestamp(mktime(x)))
    .astype("datetime64[ns]")
    )

clean_all = (
    mutate(
        date_added = convert_date(_.date_added),
        date_modified = convert_date(_.date_modified),
        skip_date = convert_date(_.skip_date)
    ) >>
    select(
        _.contains("date"),
        _.artist, _.name, _.album, _.genre, _.kind,
        _.persistent_id, _.play_count,
        _.rating, _.skip_count, _.track_id,
        _.track_number, _.year
    ) >>
    filter(~_.date_added.isna()) # Shared playlist songs shouldn't be included
)


data1 = (
    pd.DataFrame(raw_data1) >>
    clean_all
)

data2 = (
    pd.DataFrame(raw_data2) >>
    clean_all
)

# %%
(
    data2 >>
    count(added_year = _.date_added.dt.year)
)
# Out:
#     added_year     n
# 0         2006     3
# 1         2007     2
# 2         2008     3
# 3         2009     3
# 4         2010     6
# 5         2011   133
# 6         2012   171
# 7         2013   114
# 8         2014    48
# 9         2015    48
# 10        2016   241
# 11        2017   848
# 12        2018  1314
# 13        2019  4261

# %% [markdown]
# ## Why are some added dates missing from the 2019 lib?

# %%
# print(
#     data1.shape,
#     data2.shape,
#     joined.shape
#     )

print(
    data1.date_added.isna().sum(),
    data2.date_added.isna().sum()
    )
# Out:
# 0 0

# %%
(
    data2
    >> group_by(_.artist)
    >> summarize(ttl_na=_.date_added.isna().sum())
    >> arrange(-_.ttl_na)
).head()
# Out:
#                      artist  ttl_na
# 0       "Weird Al" Yankovic       0
# 1                      10cc       0
# 2                  2 Chainz       0
# 3                 21 Savage       0
# 4  21 Savage & Metro Boomin       0

# %%
# data2 >> filter(_.artist == "Mura Masa")

# %% [markdown]
# Aha! Songs for shared playlists appear in the library but have not been "added". It is safe to exclude them.

# %% [markdown]
# ### Match songs from 2016 <=> 2019

# %% [markdown]
# There should be three dataframes that will need to be concatenated:
# 1. `joined_on_pid`, the songs that were not changed (they had the same persistent_id in 2016 as 2019);
# 2. `joined`, the songs that were matched (exactly) using artist and name (excluding `joined_on_pid`);
# 3. And `manually_joined`, the songs that are not included in the above DFs but by eyeballing should have been matched.

# %%
# (
#     data1 >>
#     inner_join(_, data2, on = "track_id") >>
#     pipe(lambda d: d[sorted(d.columns)])
# )
# Track id is not enough to use as a join key

# %%
# Use persistent_id to match songs, then remove those from future attempts to join
joined_on_pid = (
    data1 >>
    inner_join(_, data2, on = "persistent_id") >>
    pipe(lambda d: d[sorted(d.columns)])
)

# %%
joined = (
    data1
    # anti_join(joined_on_pid, on = 'persistent_id')
    >> left_join(
        _,
        joined_on_pid >> select(_.persistent_id) >> mutate(in_pid_table=True),
        on="persistent_id",
    )
    >> filter(_.in_pid_table.isna())
    >> inner_join(_, data2, on=["name", "artist"])
    >> pipe(lambda d: d[sorted(d.columns)])
)

# %%
# Get everything from data1 that is not in the above two DataFrames.
manually_joined_raw = (
    data1 
)

# %% [markdown]
# ### Update metadata

# %% [markdown]
# Metadata to change:
# - date_added
# - play_count
# - skip_count
# - genre

# %% [markdown]
# #### date_added

# %%
(
    joined_on_pid >>
        mutate(date_added = _.apply(lambda d: d.date_added_x if (d.date_added_x < d.date_added_y) else d.date_added_y))
#         mutate(date_added = case_when({
#                 _.date_added_x < _.date_added_y: _.date_added_x,
#                 True: _.date_added_y
#         }))
#         count(t = _.date_added_x > _.date_added_y)
#         mutate(date_added = )
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-8cc87a5b8e9f> in <module>
#       1 (
#       2     joined_on_pid >>
# ----> 3         mutate(date_added = _.apply(lambda d: d.date_added_x if (d.date_added_x < d.date_added_y) else d.date_added_y))
#       4 #         mutate(date_added = case_when({
#       5 #                 _.date_added_x < _.date_added_y: _.date_added_x,
#
# /usr/local/lib/python3.7/site-packages/siuba/dply/verbs.py in __rrshift__(self, x)
#      73             return Pipeable(calls = [x] + self.calls)
#      74
# ---> 75         return self(x)
#      76
#      77     def __call__(self, x):
#
# /usr/local/lib/python3.7/site-packages/siuba/dply/verbs.py in __call__(self, x)
#      78         res = x
#      79         for f in self.calls:
# ---> 80             res = f(res)
#      81         return res
#      82
#
# /usr/local/lib/python3.7/site-packages/siuba/siu.py in __call__(self, x)
#     161
#     162         # in normal case, get method to call, and then call it
# --> 163         return getattr(inst, self.func)(*rest, **kwargs)
#     164
#     165     @staticmethod
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/functools.py in wrapper(*args, **kw)
#     825                             '1 positional argument')
#     826
# --> 827         return dispatch(args[0].__class__)(*args, **kw)
#     828
#     829     funcname = getattr(func, '__name__', 'singledispatch function')
#
# /usr/local/lib/python3.7/site-packages/siuba/dply/verbs.py in mutate(__data, **kwargs)
#     244     """
#     245
# --> 246     return __data.assign(**kwargs)
#     247
#     248
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in assign(self, **kwargs)
#    3647         if PY36:
#    3648             for k, v in kwargs.items():
# -> 3649                 data[k] = com.apply_if_callable(v, data)
#    3650         else:
#    3651             # <= 3.5: do all calculations first...
#
# /usr/local/lib/python3.7/site-packages/pandas/core/common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     363
#     364     if callable(maybe_callable):
# --> 365         return maybe_callable(obj, **kwargs)
#     366
#     367     return maybe_callable
#
# /usr/local/lib/python3.7/site-packages/siuba/siu.py in __call__(self, x)
#     161
#     162         # in normal case, get method to call, and then call it
# --> 163         return getattr(inst, self.func)(*rest, **kwargs)
#     164
#     165     @staticmethod
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6904             kwds=kwds,
#    6905         )
# -> 6906         return op.get_result()
#    6907
#    6908     def applymap(self, func):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# <ipython-input-76-8cc87a5b8e9f> in <lambda>(d)
#       1 (
#       2     joined_on_pid >>
# ----> 3         mutate(date_added = _.apply(lambda d: d.date_added_x if (d.date_added_x < d.date_added_y) else d.date_added_y))
#       4 #         mutate(date_added = case_when({
#       5 #                 _.date_added_x < _.date_added_y: _.date_added_x,
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5178             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5179                 return self[name]
# -> 5180             return object.__getattribute__(self, name)
#    5181
#    5182     def __setattr__(self, name, value):
#
# AttributeError: ("'Series' object has no attribute 'date_added_x'", 'occurred at index album_x')

# %% [markdown]
# #### Play Count

# %%
# for joined_on_pid, we want to keep the most recent playcount number.
(
    joined_on_pid 
    >> select(_.contains("play_count")) 
    >> count(old_plays_is_larger = _.play_count_x > _.play_count_y)
)
# Out:
#    old_plays_is_larger    n
# 0                False  540

# %% [markdown]
# #### Skip Count

# %%
# for joined_on_pid, we want to keep the most recent skip count number.
(
    joined_on_pid 
    >> select(_.contains("skip_count")) 
    >> count(old_skips_is_larger = _.skip_count_x > _.skip_count_y)
)
# Out:
#    old_skips_is_larger    n
# 0                False  540

# %% [markdown]
# #### Genre

# %%
(
    data2
    >> count(_.genre, sort = True)
    >> arrange(_.genre, _.n)
)
# Out:
#                  genre    n
# 0   Action & Adventure    2
# 1   Adult Contemporary    2
# 2          Alternative  319
# 3            Bluegrass    1
# 4                Blues    4
# ..                 ...  ...
# 57               Vocal   18
# 58          Vocal Jazz    9
# 59           Vocal Pop   26
# 60          Voice Memo    2
# 61               World    2
#
# [62 rows x 2 columns]

# %%
genre_map = {
    'East Coast Rap': 'Hip-Hop/Rap',
    'Gangsta Rap': 'Hip-Hop/Rap',
    'Hardcore Rap': 'Hip-Hop/Rap',
    'Hip Hop/Rap': 'Hip-Hop/Rap',
    'Hip-Hop': 'Hip-Hop/Rap',
    'Hip-hop & Rap': 'Hip-Hop/Rap',
    'Rap': 'Hip-Hop/Rap',
    'R&B': 'R&B/Soul',
    'Soul': 'R&B/Soul',
    'Traditional Folk': 'Folk',
    'Trance': 'Dance',
}

# %% [markdown]
# ### Hunt for duplicates
